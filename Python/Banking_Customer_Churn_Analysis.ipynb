# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\C DRIVE\Documents\Churn_Modelling.csv")
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
print("Total Customers:", len(df))
# Out:
# Total Customers: 10000

# %%
print("Churned Customers:", df['Exited'].sum())
# Out:
# Churned Customers: 2037

# %%
print("Churn Rate:", round(df['Exited'].mean()*100,2), "%")
# Out:
# Churn Rate: 20.37 %

# %%
print("Average Age:", round(df['Age'].mean(),2))
# Out:
# Average Age: 38.92

# %%
print("Youngest Age:", df['Age'].min())
print("Oldest Age:", df['Age'].max())
# Out:
# Youngest Age: 18
# Oldest Age: 92

# %%
df['Geography'].value_counts().head(1)
# Out:
# Geography
# France    5014
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
print("Average Balance:", round(df['Balance'].mean(),2))
# Out:
# Average Balance: 76485.89

# %%
df.nlargest(1,'Balance')[['CustomerId','Balance']]
# Out:
#       CustomerId    Balance
# 2092    15757408  250898.09

# %%
df.nlargest(1,'EstimatedSalary')[['CustomerId','EstimatedSalary']]
# Out:
#       CustomerId  EstimatedSalary
# 6646    15662021        199992.48

# %%
df['IsActiveMember'].value_counts()
# Out:
# IsActiveMember
# 1    5151
# 0    4849
# Name: count, dtype: int64

# %%
df[df['NumOfProducts'] > 2].shape[0]
# Out:
# 326

# %%
print("Average Credit Score:", round(df['CreditScore'].mean(),2))
# Out:
# Average Credit Score: 650.53

# %%
df[df['Balance'] == 0].shape[0]
# Out:
# 3617

# %%
print("Average Tenure:", round(df['Tenure'].mean(),2))
# Out:
# Average Tenure: 5.01

# %%
country_counts = df['Geography'].value_counts()

plt.figure(figsize=(6,4))
plt.bar(country_counts.index, country_counts.values)
plt.title('Customers by Country')
plt.xlabel('Country')
plt.ylabel('Number of Customers')
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df['Age'], bins=10)
plt.title('Customer Age Distribution')
plt.xlabel('Age')
plt.ylabel('Number of Customers')
plt.show()
